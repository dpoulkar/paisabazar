# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    -EDA Paisabazaar Banking Fraud Analysis
# ##### **Contribution**    -Individual
# ##### **Team Member 1**     -Dnyaneshwar Limbaji Poulkar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Paisabazaar is a financial services company that assists customers in finding and applying for various banking and credit products. An integral part of their service is assessing the creditworthiness of individuals, which is crucial for both loan approval and risk management. The credit score of a person is a significant metric used by financial institutions to determine the likelihood that an individual will repay their loans or credit balances. Accurate classification of credit scores can help Paisabazaar enhance their credit assessment processes, reduce the risk of loan defaults, and offer personalized financial advice to their customers.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Paisabazaar Banking Fraud Analysis

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To improve credit risk management and customer targeting by analyzing financial behavior patterns (e.g., income, debt, loan count, and payment behavior), enabling data-driven decisions for reducing loan defaults, enhancing credit score accuracy, and offering personalized financial products.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv('/content/dataset module 2 project.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()

# %%
# Visualizing the missing values
sns.heatmap(data.isnull(),cbar=True)

# %% [markdown]
# In this dataset there are total 100000 rows and 28 columns. There is 0 non null values and also 0 duplicate records

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns

# %%
# Dataset Describe
data.describe()

# %% [markdown]
# Variables Description

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data.unique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# If there are any duplictae value drop them
data.drop_duplicates(inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I drop a duplicte record if any present and also check for null values but there is 0 not null values.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
sns.histplot(data=data,x='Annual_Income',bins=50)
plt.title("Annual Income Count")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because histplot is used for univriate analysis of numerical column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most of people annual income is between 10000 to 50000

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes is hepls creating a positive business impact because by this this company targets people which having this range of annual income.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.barplot(data=data,x='Occupation',y='Annual_Income')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Beacuse barplot is used for bivariate analysis of cataegorical and numerical column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The annual income of architect is high.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this analysis we know that the annual income of Journalist is low and we approach them to get the laon.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.barplot(data=data,x='Occupation',y='Num_of_Delayed_Payment')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Beacuse barplot is used for bivariate analysis of cataegorical and numerical column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this analysis we conclude that Teachers are pay bit earlier than others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact:
#
# From this analysis we see that scientist have a most number of delays in payment so we give early alert

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
sns.boxplot(x='Credit_Score', y='Annual_Income', data=data)
plt.title('Annual Income by Credit Score Category')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The boxplot is ideal for visualizing the distribution of a numerical variable across different categories of a categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Poor credit score group shows more income variability and a greater number of low-income outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact:
#
# Financial institutions can use this to target high-income individuals in the Standard category for credit improvement programs or personalized loan products.
#
# It helps design risk-based loan offerings – customers with low income and poor scores may be offered smaller, more secure loans.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
sns.countplot(x='Credit_Score', data=data)
plt.title('Distribution of Credit Score Categories')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is the best choice to visualize the frequency (count) of observations in each credit score category — such as Good, Standard, and Poor.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of customers fall under the Standard credit score category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights will help create a positive business impact:
#
# Customer segmentation based on credit score allows banks or financial institutions to tailor loan products, interest rates, or credit cards more effectively.
#
# Businesses can identify and reward Good score holders with better benefits to increase customer loyalty.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.scatterplot(x='Outstanding_Debt', y='Monthly_Balance', hue='Credit_Score', data=data)
plt.title('Outstanding Debt vs Monthly Balance')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for analyzing the relationship between two continuous numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As Outstanding Debt increases, Monthly Balance tends to decrease, especially beyond 2000

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can support positive business decisions:
#
# Helps in risk assessment: Customers with high debt and low balance can be flagged as high risk, especially if they belong to the Poor score category.
#
# Enables credit scoring model improvement by integrating behavioral data.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
sns.lineplot(x='Age', y='Total_EMI_per_month', data=data)
plt.title('EMI per Month vs Age')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is suitable for observing trends over a continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Younger individuals (10-20) may have higher Total EMI per month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights support positive business impact:
#
# Lenders can target middle-aged groups for high-value loan products like home or education loans.
#
# Young professionals may be targeted for starter loans or credit-building programs.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
sns.barplot(x='Occupation', y='Num_of_Loan', data=data)
plt.xticks(rotation=45)
plt.title('Average Number of Loans by Occupation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is ideal when comparing the average value of a numerical column across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Doctor may show higher average number of loans, possibly due to business financing needs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight can positively impact business strategy:
#
# Lenders can create custom loan packages tailored to high-loan-need groups.
#
# Occupations with lower loan counts may benefit from awareness campaigns or credit education to improve engagement

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
sns.countplot(x='Payment_Behaviour', hue='Credit_Score', data=data)
plt.xticks(rotation=45)
plt.title('Payment Behavior by Credit Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot with hue='Credit_Score' is ideal to visualize the frequency of payment behaviors and how they differ across credit score categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows the highest count of payment behaviour is Low Spent Medium Value Payments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this chart offers actionable insights for business benefit:
#
# Financial institutions can reward good behaviors (e.g., offers for those paying full amount on time).
#
# Customers showing risky behavior can be flagged for alerts, reminders, or counseling.

# %% [markdown]
# #### Chart - 10 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
selected_cols = ['Age','Annual_Income','Monthly_Inhand_Salary','Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt','Credit_Utilization_Ratio','Credit_History_Age',
'Total_EMI_per_month','Amount_invested_monthly','Monthly_Balance']
important_data = data[selected_cols]

# Calculate correlation matrix
corr_matrix = important_data.corr()

# Plot heatmap
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Key Financial Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap of the correlation matrix is chosen to visually explore the relationships between numerical variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Monthly_Inhand_Salary may show a strong positive correlation with Annual_Income.
#
# 2.Monthly_Inhand_Salary may show a strong positive correlation with Annual_Invested_monthly.

# %% [markdown]
# #### Chart - 11 - Pair Plot

# %%
# Pair Plot visualization code
selected_cols = data[['Annual_Income','Num_of_Loan','Outstanding_Debt','Monthly_Balance','Credit_Score']]
sns.pairplot(data=selected_cols, hue='Credit_Score')
plt.suptitle("Pair Plot of Key Financial Metrics by Credit Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is chosen because it allows us to visually explore the relationships between multiple numerical variables in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Optimize lending decisions, reduce default risk, and improve customer segmentation for better credit services.
#
# Use key features like payment behavior, credit utilization, and outstanding debt to create clear customer profiles.
#
# Target Good credit score customers with pre-approved offers, low-interest loans, and premium products.
#
# Design improvement programs (credit coaching, reminders, or limit adjustments) for Standard/Poor credit score customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The annual income of architect is high compare to another.
#
# Monthly_Inhand_Salary may show a strong positive correlation with Annual_Invested_monthly.
#
# From this analysis we conclude that Teachers are pay bit earlier than others.
#
# The majority of customers fall under the Standard credit score category.
#
# Younger individuals (10-20) may have higher Total EMI per month.
#
# Doctor may show higher average number of loans, possibly due to business financing needs

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
